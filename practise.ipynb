# %%
listone = [1,2,3,]
listtwo = [4,5,6]

new_list = listone + listtwo
print(new_list)

if len(new_list)%2 == 1:
    mid = len(new_list)/ 2
    print(new_list[mid])

else:
    mid = len(new_list) / 2 
    front = mid + 1
    mid= (new_list[mid] + new_list [front] )/ 2 
    print(mid)
# Out:
# [1, 2, 3, 4, 5, 6]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 14
#      10
#      11 else:
#      12     mid = len(new_list) / 2
#      13     front = mid + 1
# ---> 14     mid= (new_list[mid] + new_list [front] )/ 2
#      15     print(mid)
#
# TypeError: list indices must be integers or slices, not float
