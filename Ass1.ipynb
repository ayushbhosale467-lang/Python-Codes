# %%
name = "Ayush Bhosale"
age = 21
college_name = "Ajeenkya DY Patil School of Engineering"
city = "Pune"
course_name = "Computer Engineering"

print("----- Student Information -----")
print("Name         :", name)
print("Age          :", age)
print("College Name :", college_name)
print("City         :", city)
print("Course Name  :", course_name)
print("-------------------------------")
# Out:
# ----- Student Information -----
# Name         : Ayush Bhosale
# Age          : 21
# College Name : Ajeenkya DY Patil School of Engineering
# City         : Pune
# Course Name  : Computer Engineering
# -------------------------------

# %%
# Creating variables
student_name = "Ayush Bhosale"
roll_number = 25
branch = "Computer Engineering"
percentage = 87.5
passed = True

# Displaying the information
print("----- Student Details -----")
print("Student Name :", student_name)
print("Roll Number  :", roll_number)
print("Branch       :", branch)
print("Percentage   :", percentage, "%")
print("Passed       :", passed)
print("---------------------------")
# Out:
# ----- Student Details -----
# Student Name : Ayush Bhosale
# Roll Number  : 25
# Branch       : Computer Engineering
# Percentage   : 87.5 %
# Passed       : True
# ---------------------------

# %%
# College Management System Variables

student_name = "Ayush Bhosale"
roll_no = 25
branch = "Computer Engineering"
semester = 5
college_name = "Ajeenkya DY Patil School of Engineering"
city = "Pune"
attendance_percentage = 92.5
fee_paid = True
email_id = "ayushbhosale25@gmail.com"
cgpa = 8.45

# Printing all variables
print("----- College Management System -----")
print("Student Name           :", student_name)
print("Roll Number            :", roll_no)
print("Branch                 :", branch)
print("Semester               :", semester)
print("College Name           :", college_name)
print("City                   :", city)
print("Attendance Percentage  :", attendance_percentage)
print("Fee Paid               :", fee_paid)
print("Email ID               :", email_id)
print("CGPA                   :", cgpa)
print("--------------------------------------")
# Out:
# ----- College Management System -----
# Student Name           : Ayush Bhosale
# Roll Number            : 25
# Branch                 : Computer Engineering
# Semester               : 5
# College Name           : Ajeenkya DY Patil School of Engineering
# City                   : Pune
# Attendance Percentage  : 92.5
# Fee Paid               : True
# Email ID               : ayushbhosale25@gmail.com
# CGPA                   : 8.45
# --------------------------------------

# %%
# This program prints a short introduction

# Storing personal details
name = "Ayush Bhosale"
city = "Pune"
course = "Computer Engineering"

"""
This is a multi-line comment.
The program uses variables to store
basic information and then displays
a short introduction.
"""

# Printing the introduction
print("----- My Introduction -----")
print("Hello! My name is", name)
print("I am from", city)
print("I am studying", course)
print("I enjoy learning new technologies and improving my skills.")
print("Thank you!")
# Out:
# ----- My Introduction -----
# Hello! My name is Ayush Bhosale
# I am from Pune
# I am studying Computer Engineering
# I enjoy learning new technologies and improving my skills.
# Thank you!

# %%
# Valid identifiers with values

student2 = "Ayush"
student_name = "Rahul"
student_name_full = "Priya Sharma"
class_name = "TE Computer"
for_loop_count = 10
employee_id = 101

# Printing the variables
print("student2 =", student2)
print("student_name =", student_name)
print("student_name_full =", student_name_full)
print("class_name =", class_name)
print("for_loop_count =", for_loop_count)
print("employee_id =", employee_id)
# Out:
# student2 = Ayush
# student_name = Rahul
# student_name_full = Priya Sharma
# class_name = TE Computer
# for_loop_count = 10
# employee_id = 101
