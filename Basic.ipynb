# %%
print("hello world")
# Out:
# hello world

# %%
name = "Ayush Namdev Bhosale"
age = "21"
collage_name = "ADYPSOE"
city = "pune"
course = "computer enginnering"

print("Name:",name)
print("age is:",age)
print("collages name is:",collage_name)
print("city :",city)
print("course is:",course)
# Out:
# Name: Ayush Namdev Bhosale
# age is: 21
# collages name is: ADYPSOE
# city : pune
# course is: computer enginnering
